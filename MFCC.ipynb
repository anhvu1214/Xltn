# %% [markdown]
# <a href="https://colab.research.google.com/github/anhvu1214/Xltn/blob/main/MFCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import IPython.display as ipd
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
audio_file = "/content/drive/MyDrive/Hoc/Xltn/Audio/A.wav"
# Out:
# Mounted at /content/drive

# %%
ipd.Audio(audio_file)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal, sr = librosa.load(audio_file)
mfccs = librosa.feature.mfcc(y=signal, n_mfcc=13, sr=sr)
mfccs.shape
# Out:
# (13, 15)

# %%
delta_mfccs = librosa.feature.delta(mfccs)
delta2_mfccs = librosa.feature.delta(mfccs, order=2)
mfccs_features = np.concatenate((mfccs, delta_mfccs, delta2_mfccs))
mfccs_features
# Out:
# array([[-5.59605530e+02, -4.54435181e+02, -3.80907501e+02,
#         -3.62533508e+02, -3.72825500e+02, -3.84881531e+02,
#         -3.90076843e+02, -4.05012787e+02, -4.27635773e+02,
#         -4.60010162e+02, -4.97963959e+02, -5.33072937e+02,
#         -5.66330566e+02, -5.87198242e+02, -6.03813477e+02],
#        [ 1.35024109e+02,  1.49047913e+02,  1.58184326e+02,
#          1.51699371e+02,  1.41717438e+02,  1.43250931e+02,
#          1.43404343e+02,  1.43071472e+02,  1.40397614e+02,
#          1.39521271e+02,  1.41477448e+02,  1.38259979e+02,
#          1.31995331e+02,  1.25190987e+02,  1.23953712e+02],
#        [ 3.26969757e+01, -3.98553391e+01, -7.96650543e+01,
#         -8.80599213e+01, -9.00593262e+01, -8.34297180e+01,
#         -7.70571365e+01, -7.23257141e+01, -6.21863556e+01,
#         -4.36536369e+01, -2.16620293e+01, -7.07613182e+00,
#          1.18617582e+01,  3.05634270e+01,  4.85981598e+01],
#        [ 1.75115871e+01,  1.36812229e+01,  1.40633621e+01,
# ...
